# %% [markdown]
# # Random Forest Assignment

# %% [markdown]
# *Prafful Agrawal*
# *13/02/2021*

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# Build a random forest model using *scikit learn* in **boston data** to predict 'Price' based on other dependent variable.

# %% [markdown]
# ### Solution

# %% [markdown]
# The analysis has been divided into the following steps:
#
# 1. Data Import
# 2. Exploratory Data Analysis
# 3. Data Preprocessing and Transformation
# 4. Model Development
# 5. Model Tuning and Verification
# 6. Conclusion

# %% [markdown]
# Let us import the required packages.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Now, load the *Boston Data* as a Pandas Dataframe.

# %%
from sklearn.datasets import load_boston
boston_data = load_boston()
X = pd.DataFrame(boston_data.data, columns = boston_data.feature_names)
y = pd.Series(boston_data.target, name = 'MEDV')
data = X.join(y)

# %% [markdown]
# Look at the first few rows.

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# The description of the data is as given below:

# %%
print(boston_data.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %% [markdown]
# There are **13 independent variables** which can be used to predict the **dependent variable** `MEDV`. There are a total of 506 observations.

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %% [markdown]
# The variables `CHAS` and `RAD` are categorical variables while the rest are numerical variables.
#
# Let us check for missing values.

# %%
data.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# It seems that there are no missing values in our data.
#
# Let us look at the distribution of data:

# %%
plt.figure(figsize = (20, 40))
plotnumber = 1
for column in data.columns[:-1]:
    ax = plt.subplot(5, 3, plotnumber)
    sns.histplot(data = data[column], stat = 'count', kde = True)
    plt.xlabel(column, fontsize = 16)
    plt.ylabel('Count', fontsize = 16)
    plotnumber += 1
plt.show()

# %% [markdown]
# Multiple variables show considerable skewness. We can transform these to reduce their skewness.
#
# We will replace the variables `CRIM`, `DIS` and `B` with their *logarithms*. While, for the variable `ZN`, we will use *square roots* (since it has values equal to Zero).

# %%
data_trans = data.copy()
data_trans[['CRIM', 'DIS', 'B']] = np.log(data[['CRIM', 'DIS', 'B']])
data_trans['ZN'] = np.sqrt(data['ZN'])
data_trans
# Out:
#          CRIM        ZN  INDUS  CHAS    NOX     RM   AGE       DIS  RAD  \
# 0   -5.064036  4.242641   2.31   0.0  0.538  6.575  65.2  1.408545  1.0
# 1   -3.600502  0.000000   7.07   0.0  0.469  6.421  78.9  1.602836  2.0
# 2   -3.601235  0.000000   7.07   0.0  0.469  7.185  61.1  1.602836  2.0
# 3   -3.430523  0.000000   2.18   0.0  0.458  6.998  45.8  1.802073  3.0
# 4   -2.672924  0.000000   2.18   0.0  0.458  7.147  54.2  1.802073  3.0
# ..        ...       ...    ...   ...    ...    ...   ...       ...  ...
# 501 -2.770511  0.000000  11.93   0.0  0.573  6.593  69.1  0.907694  1.0
# 502 -3.095111  0.000000  11.93   0.0  0.573  6.120  76.7  0.827460  1.0
# 503 -2.800824  0.000000  11.93   0.0  0.573  6.976  91.0  0.773574  1.0
# 504 -2.211009  0.000000  11.93   0.0  0.573  6.794  89.3  0.870833  1.0
# 505 -3.048922  0.000000  11.93   0.0  0.573  6.030  80.8  0.918289  1.0
#
#        TAX  PTRATIO         B  LSTAT  MEDV
# 0    296.0     15.3  5.983684   4.98  24.0
# 1    242.0     17.8  5.983684   9.14  21.6
# 2    242.0     17.8  5.973377   4.03  34.7
# 3    222.0     18.7  5.977949   2.94  33.4
# 4    222.0     18.7  5.983684   5.33  36.2
# ..     ...      ...       ...    ...   ...
# 501  273.0     21.0  5.971236   9.67  22.4
# 502  273.0     21.0  5.983684   9.08  20.6
# 503  273.0     21.0  5.983684   5.64  23.9
# 504  273.0     21.0  5.974954   6.48  22.0
# 505  273.0     21.0  5.983684   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# Again, look at the distribution of the transformed variables.

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1
for column in ['CRIM', 'ZN', 'DIS', 'B']:
    ax = plt.subplot(2, 3, plotnumber)
    sns.histplot(data = data_trans[column], stat = 'count', kde = True)
    plt.xlabel(column, fontsize = 16)
    plt.ylabel('Count', fontsize = 16)
    plotnumber += 1
plt.show()

# %% [markdown]
# There are some improvements in the above distributions but the variable `B` still looks the same. This may be the result of outliers.
#
# Let us check for outliers in our data using boxplots.

# %%
plt.figure(figsize = (20, 20))
plotnumber = 1
for column in data_trans.columns[:-1]:
    ax = plt.subplot(3, 5, plotnumber)
    sns.boxplot(y = data_trans[column], width = 0.25)
    plt.xlabel(column, fontsize = 16)
    plt.ylabel('')
    plotnumber += 1
plt.show()

# %% [markdown]
# Many of the given variables suffer from outliers.
#
# We can calculate the number of outliers per column using the Inter-Quartile Range (IQR) as follows:

# %%
dt_q25 = data_trans.quantile(0.25)
dt_q75 = data_trans.quantile(0.75)
IQR = dt_q75 - dt_q25
is_Outlier = (data_trans < (dt_q25 - 1.5 * IQR)) | (data_trans > (dt_q75 + 1.5 * IQR))
is_Outlier = is_Outlier.drop(columns = 'MEDV')
num_Outliers = is_Outlier.sum()
num_Outliers
# Out:
# CRIM        0
# ZN         29
# INDUS       0
# CHAS       35
# NOX         0
# RM         30
# AGE         0
# DIS         0
# RAD         0
# TAX         0
# PTRATIO    15
# B          78
# LSTAT       7
# dtype: int64

# %% [markdown]
# From above, we can observe that out of 13 variables, 6 have outliers.
#
# The variable `B` has the most outliers, followed by the variable `CHAS` and then `RM` and `ZN` respectively.
#
# On careful consideration, we have decided to drop the variables `B` and `CHAS` completely (due to high fraction of outliers), while for the remaining variables we will remove the observations having outliers in any of their column.

# %%
data_out_rem = data_trans.drop(columns = ['B', 'CHAS'])
data_out_rem = data_out_rem[~is_Outlier.drop(columns = ['B', 'CHAS']).any(axis = 1)]
data_out_rem
# Out:
#          CRIM        ZN  INDUS    NOX     RM   AGE       DIS  RAD    TAX  \
# 0   -5.064036  4.242641   2.31  0.538  6.575  65.2  1.408545  1.0  296.0
# 1   -3.600502  0.000000   7.07  0.469  6.421  78.9  1.602836  2.0  242.0
# 2   -3.601235  0.000000   7.07  0.469  7.185  61.1  1.602836  2.0  242.0
# 3   -3.430523  0.000000   2.18  0.458  6.998  45.8  1.802073  3.0  222.0
# 4   -2.672924  0.000000   2.18  0.458  7.147  54.2  1.802073  3.0  222.0
# ..        ...       ...    ...    ...    ...   ...       ...  ...    ...
# 501 -2.770511  0.000000  11.93  0.573  6.593  69.1  0.907694  1.0  273.0
# 502 -3.095111  0.000000  11.93  0.573  6.120  76.7  0.827460  1.0  273.0
# 503 -2.800824  0.000000  11.93  0.573  6.976  91.0  0.773574  1.0  273.0
# 504 -2.211009  0.000000  11.93  0.573  6.794  89.3  0.870833  1.0  273.0
# 505 -3.048922  0.000000  11.93  0.573  6.030  80.8  0.918289  1.0  273.0
#
#      PTRATIO  LSTAT  MEDV
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# 3       18.7   2.94  33.4
# 4       18.7   5.33  36.2
# ..       ...    ...   ...
# 501     21.0   9.67  22.4
# 502     21.0   9.08  20.6
# 503     21.0   5.64  23.9
# 504     21.0   6.48  22.0
# 505     21.0   7.88  11.9
#
# [438 rows x 12 columns]

# %% [markdown]
# We have **438 rows** remaining and have droped a total of **68 rows**.
#
# Let us look at the relationship between the dependent and independent variables.

# %%
plt.figure(figsize = (20, 30))
plotnumber = 1
for column in data_out_rem.columns[:-1]:
    ax = plt.subplot(4, 3, plotnumber)
    sns.regplot(x = data_out_rem[column], y = data_out_rem['MEDV'])
    plt.xlabel(column, fontsize = 16)
    plt.ylabel('MEDV', fontsize = 16)
    plotnumber += 1
plt.show()

# %% [markdown]
# The relationship between the dependent and independent variables look fairly linear.
#
# Now, let us check for multicollinearity between the independent variables. For this, we can either use the Variance Inflation Factor (VIF) or the Correlation Matrix. We will first calculate VIF.

# %%
scaler = StandardScaler()
variables = scaler.fit_transform(data_out_rem.drop(columns = 'MEDV'))
vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(variables, i) for i in range(variables.shape[1])]
vif["Features"] = data_out_rem.columns[:-1]
vif
# Out:
#          VIF Features
# 0   7.289598     CRIM
# 1   1.982335       ZN
# 2   3.769269    INDUS
# 3   4.604196      NOX
# 4   1.679936       RM
# 5   2.877077      AGE
# 6   4.603866      DIS
# 7   9.829757      RAD
# 8   8.445246      TAX
# 9   1.573490  PTRATIO
# 10  2.639274    LSTAT

# %% [markdown]
# The 3 variables `CRIM`, `RAD` and `TAX` have VIF above the threshold value of 5.
#
# We proceed to construct the Correlation Matrix.

# %%
plt.figure(figsize = (12, 6))
sns.heatmap(data_out_rem.drop(columns = 'MEDV').corr(), annot = True, cmap = 'coolwarm')
plt.show()

# %% [markdown]
# The correlation between the above three variables is also high (above 0.8). This *confirms* multicollinearity.
#
# Now, to remedy this, we drop the variables `RAD` and `TAX`. The resultant data is taken as the input for model development next.

# %%
X = data_out_rem.drop(columns = ['RAD', 'TAX', 'MEDV'])
y = data_out_rem['MEDV']

# %% [markdown]
# Let us split the data into the training and testing set.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 123)

# %% [markdown]
# Fit a random forest regressor.

# %%
rfr = RandomForestRegressor(oob_score = True, random_state = 123)
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(oob_score=True, random_state=123)

# %% [markdown]
# The $R^2$ score of the model is:

# %%
rfr.score(X_test, y_test)
# Out:
# 0.8537033280737056

# %% [markdown]
# Now, let us try to tune some hyper-parameters using the `GridSearchCV` algorithm.
#
# We will tune the given 5 hyper-parameters:
#
# 1. `n_estimators` - number of trees in the forest
# 2. `criterion` - function to measure the quality of a split
# 3. `min_samples_split` - minimum number of samples required to split an internal node
# 4. `max_features` - number of features to consider when looking for the best split
# 5. `max_samples` - number of samples to draw from X to train each base estimator
#
# We will use a *5-fold* cross validation. And, also fix the `random_state` for reproducibility.

# %%
param_grid = {'n_estimators' : [50, 100, 150],
              'criterion' : ['mse', 'mae'],
              'min_samples_split' : range(2, 8, 1),
              'max_features' : ['auto', 'sqrt'],
              'max_samples' : [0.25, 0.5, 0.75],
              'random_state' : [123]}

# Define an instance
gsCV = GridSearchCV(estimator = rfr,
                    param_grid = param_grid,
                    n_jobs = -1,
                    cv = 5,
                    verbose = 3)

# %% [markdown]
# Fit the training data using `GridSearchCV` instance.

# %%
gsCV.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:   37.0s
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 1080 out of 1080 | elapsed:  1.7min finished
# GridSearchCV(cv=5,
#              estimator=RandomForestRegressor(oob_score=True, random_state=123),
#              n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae'],
#                          'max_features': ['auto', 'sqrt'],
#                          'max_samples': [0.25, 0.5, 0.75],
#                          'min_samples_split': range(2, 8),
#                          'n_estimators': [50, 100, 150],
#                          'random_state': [123]},
#              verbose=3)

# %% [markdown]
# The parameters for the best tuned estimator are given below:

# %%
gsCV.best_params_
# Out:
# {'criterion': 'mae',
#  'max_features': 'sqrt',
#  'max_samples': 0.75,
#  'min_samples_split': 4,
#  'n_estimators': 150,
#  'random_state': 123}

# %% [markdown]
# Now, fit a random forest regressor using this estimator.

# %%
rfr_tuned = gsCV.best_estimator_
rfr_tuned.fit(X_train, y_train)
# Out:
# RandomForestRegressor(criterion='mae', max_features='sqrt', max_samples=0.75,
#                       min_samples_split=4, n_estimators=150, oob_score=True,
#                       random_state=123)

# %% [markdown]
# Again, the $R^2$ score of the tuned model is:

# %%
rfr_tuned.score(X_test, y_test)
# Out:
# 0.863287192238951

# %% [markdown]
# Hence, the accuracy has improved by parameter tuning.
#
# In conclusion, we have developed a linear regression model using Random Forest algorithm.
